# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt

import numpy as np

# %%
restaurant = pd.read_csv("zomato.csv", encoding='ISO-8859-1')
country_code = pd.read_excel("Country-Code.xlsx")

# %%
restaurant = restaurant.merge(country_code, on='Country Code', how='left')

# %%
indian_restaurants = restaurant[restaurant['Country'] == 'India']
singapore_restaurants = restaurant[restaurant['Country'] == 'Singapore']
Us_restaurants = restaurant[restaurant['Country'] == 'United States']
Uk_restaurants = restaurant[restaurant['Country'] == 'United Kingdom']

# %%
restaurant.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
indian_restaurants.head()
# Out:
#      Restaurant ID                        Restaurant Name  Country Code  City  \
# 624        3400025                             Jahanpanah             1  Agra
# 625        3400341                    Rangrezz Restaurant             1  Agra
# 626        3400005                Time2Eat - Mama Chicken             1  Agra
# 627        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 628        3400017                         Pinch Of Spice             1  Agra
#
#                                                Address     Locality  \
# 624  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 625  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 626        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 627  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 628  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#       Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %%
indian_restaurants['City'].value_counts()
# Out:
# City
# New Delhi       5473
# Gurgaon         1118
# Noida           1080
# Faridabad        251
# Ghaziabad         25
# Ahmedabad         21
# Guwahati          21
# Lucknow           21
# Bhubaneshwar      21
# Amritsar          21
# Pune              20
# Puducherry        20
# Patna             20
# Ludhiana          20
# Ranchi            20
# Surat             20
# Vadodara          20
# Nashik            20
# Nagpur            20
# Mysore            20
# Mumbai            20
# Varanasi          20
# Mangalore         20
# Agra              20
# Kochi             20
# Kolkata           20
# Dehradun          20
# Allahabad         20
# Aurangabad        20
# Bangalore         20
# Bhopal            20
# Chennai           20
# Coimbatore        20
# Goa               20
# Indore            20
# Jaipur            20
# Kanpur            20
# Vizag             20
# Chandigarh        18
# Hyderabad         18
# Secunderabad       2
# Panchkula          1
# Mohali             1
# ...

# %%
singapore_restaurants.head()
# Out:
#      Restaurant ID       Restaurant Name  Country Code       City  \
# 456       18483372             Sky On 57           184  Singapore
# 457       18484349  Cut By Wolfgang Puck           184  Singapore
# 458       18496057      Restaurant Andre           184  Singapore
# 459       18483389      Potato Head Folk           184  Singapore
# 460       18483222                  Jaan           184  Singapore
#
#                                               Address  \
# 456    10 Bayfront Avenue, 57 Marina Bay Sands 018956
# 457  2 Bayfront Avenue, B1-71 Marina Bay Sands 018972
# 458                        41 Bukit Pasoh Road 089855
# 459                         36 Keong Saik Road 089143
# 460  2 Stamford Road, Level 70 Equinox Complex 178882
#
#                             Locality  \
# 456   Bayfront Avenue, Downtown Core
# 457  Bayfront Subzone, Downtown Core
# 458          Cantonment Road, Outram
# 459                Chinatown, Outram
# 460         City Hall, Downtown Core
#
# ...

# %%
singapore_restaurants['Locality'].value_counts()
# Out:
# Locality
# Marina Centre, Downtown Core       3
# Lavender, Kallang                  2
# Bayfront Avenue, Downtown Core     1
# Telok Ayer Street, Outram          1
# Sungai Pinang, Rochor              1
# Robertson Quay, Singapore River    1
# North Bridge Road, Rochor          1
# Neil Road, Outram                  1
# Kay Siang Road, Tanglin            1
# Bayfront Subzone, Downtown Core    1
# Hillcrest, Bukit Timah             1
# Haji Lane, Rochor                  1
# Duxton Hill, Outram                1
# City Hall, Downtown Core           1
# Chinatown, Outram                  1
# Cantonment Road, Outram            1
# Victoria, Rochor                   1
# Name: count, dtype: int64

# %%
delhi_restaurants = indian_restaurants[indian_restaurants['City'] ==' New Delhi']

# %%
delhi_restaurants.head()
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes, Country]
# Index: []
#
# [0 rows x 22 columns]

# %% [raw]
# restaruants_unqiue=restaurant['Country'].nunique()

# %%
num_india_restaurants = restaurant[restaurant['Country'] == 'India'].shape[0]
print(num_india_restaurants)
# Out:
# 8652

# %%
India = indian_restaurants['Restaurant Name'].nunique()
print(India)
# Out:
# 6604

# %%
restaurant['Country'].value_counts()
# Out:
# Country
# India             8652
# United States      434
# United Kingdom      80
# Brazil              60
# UAE                 60
# South Africa        60
# New Zealand         40
# Turkey              34
# Australia           24
# Phillipines         22
# Indonesia           21
# Singapore           20
# Qatar               20
# Sri Lanka           20
# Canada               4
# Name: count, dtype: int64

# %%
US = Us_restaurants['Restaurant Name'].nunique()
US
# Out:
# 423

# %%
delhi_top_rated = restaurant[(india_restaurant['City'].str.lower() == 'delhi') &
    (restaurant['Aggregate rating'] > 4.5)[['Aggregrete Rating','Restaurant Name','vote']].sort_values(ascending=False,by='votes')
]
# Out:
# Empty DataFrame
# Columns: [Aggregate rating, Restaurant Name, Votes]
# Index: []

# %%
Noida_TOP_rated= india_restaurant[india_restaurants['City']= "Noida"]
Sorted_Noida = Noida_TOP_rated.sort_values(

# %%
IndianCuisine=restaurant[restaurant['Country']=='India']['Cuisines'].value_counts().head()
IndianCuisine
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Fast Food                348
# Chinese                  340
# North Indian, Mughlai    334
# Name: count, dtype: int64

# %%
table=pd.pivot_table(data=restaurant,index=('Country','City'),values="Aggregate rating")
table
# Out:
#                               Aggregate rating
# Country       City
# Australia     Armidale                   3.500
#               Balingup                   3.200
#               Beechworth                 4.600
#               Dicky Beach                3.600
#               East Ballina               4.100
# ...                                        ...
# United States Valdosta                   3.715
#               Vernonia                   4.300
#               Waterloo                   3.650
#               Weirton                    3.900
#               Winchester Bay             3.200
#
# [141 rows x 1 columns]

# %%
cp= sns.light_palette("red",as_cmap=True)
table.style.background_gradient(cmap=cp,axis=0)
# Out:
# <style type="text/css">
# #T_268cb_row0_col0, #T_268cb_row5_col0, #T_268cb_row12_col0, #T_268cb_row23_col0 {
#   background-color: #f96f6f;
#   color: #f1f1f1;
# }
# #T_268cb_row1_col0, #T_268cb_row140_col0 {
#   background-color: #f88787;
#   color: #f1f1f1;
# }
# #T_268cb_row2_col0 {
#   background-color: #fe1818;
#   color: #f1f1f1;
# }
# #T_268cb_row3_col0, #T_268cb_row11_col0, #T_268cb_row22_col0, #T_268cb_row120_col0, #T_268cb_row125_col0, #T_268cb_row126_col0 {
#   background-color: #fa6767;
#   color: #f1f1f1;
# }
# #T_268cb_row4_col0, #T_268cb_row8_col0, #T_268cb_row21_col0 {
#   background-color: #fc3f3f;
#   color: #f1f1f1;
# }
# #T_268cb_row6_col0, #T_268cb_row9_col0, #T_268cb_row19_col0, #T_268cb_row26_col0, #T_268cb_row58_col0, #T_268cb_row118_col0 {
#   background-color: #fa5f5f;
#   color: #f1f1f1;
# }
# #T_268cb_row7_col0, #T_268cb_row10_col0, #T_268cb_row14_col0, #T_268cb_row85_col0 {
#   background-color: #fb5757;
#   color: #f1f1f1;
# }
# #T_268cb_row13_col0 {
# ...

# %%
sns.boxplot(x="Price range",y="Aggregate rating",data=indian_restaurants)
# Out:
# <Axes: xlabel='Price range', ylabel='Aggregate rating'>

# %%
plt.figure(figsize=(8, 6))
indian_restaurants['City'].value_counts().head().plot(kind="pie",autopct='%1.1f%%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 plt.figure(figsize=(8, 6))
#       2 indian_restaurants['City'].value_counts().head().plot(kind="pie",autopct='%1.1f%%')
#       3 plt.show()
#
# TypeError: 'module' object is not callable
